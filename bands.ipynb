# %%
from pymatgen.ext.matproj import MPRester
from IPython.display import Image
from IPython.display import display
from pymatgen.analysis.diffraction.xrd import XRDCalculator
from tabulate import tabulate
from pymatgen.io.vasp.outputs import BSVasprun, Vasprun
from pymatgen import Spin
from IPython.display import Image
from IPython.display import display, Math, Latex
from pymatgen.electronic_structure.plotter import BSPlotter, BSDOSPlotter, DosPlotter
import matplotlib.pyplot as plt
with MPRester("Osul7wWQrx1czIDzJdH7") as m:

    # Bandstructure for material id
    bs = m.get_bandstructure_by_material_id("mp-24504") 

    #plot
    bsplot = BSPlotter(bs)
    bsplot.get_plot()
    ax = plt.gca()
    ax.set_title("H2 Band Structure", fontsize=20)
    
    print("On peut voir une bande interdite de 8.07eV qui sépare la bande de valence et la bande de conduction")
    print("Le maximum de la bande de valence est à 0eV et le minimum de la bande de conduction est à 8.07eV")
    Im4=Image(filename='Img4.PNG')
    display(Im4)
    print("Sur la 2ème image on peut voir les directions selon lesquelles les bandes présentent le plus et le moins de dispersion")
# Out:
# On peut voir une bande interdite de 8.07eV qui sépare la bande de valence et la bande de conduction
# Le maximum de la bande de valence est à 0eV et le minimum de la bande de conduction est à 8.07eV
# Sur la 2ème image on peut voir les directions selon lesquelles les bandes présentent le plus et le moins de dispersion
